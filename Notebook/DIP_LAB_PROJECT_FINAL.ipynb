# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.8/906.8 kB 45.5 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
from IPython.display import Image
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
import gdown
# download  the data from google drive

url = "https://drive.google.com/file/d/1fcaBKpzuQR32fGQKexxMWhiubwY-KwC8/view?usp=sharing"
file_id = url.split('/')[-2]
print(file_id)

prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, 'sign_data.zip')
# Out:
# 1fcaBKpzuQR32fGQKexxMWhiubwY-KwC8
# Downloading...
# From: https://drive.google.com/uc?/export=download&id=1fcaBKpzuQR32fGQKexxMWhiubwY-KwC8
# To: /content/sign_data.zip
# 100%|██████████| 6.47M/6.47M [00:00<00:00, 10.9MB/s]
# 'sign_data.zip'

# %%
# !unzip sign_data.zip
# Out:
# Archive:  sign_data.zip
#   inflating: data.yaml
#    creating: test/
#    creating: test/images/
#   inflating: test/images/Hello_289_jpg.rf.134d81f2adbf896271ef1ddd071ebbe9.jpg
#   inflating: test/images/I-Love-You_109_jpg.rf.46aca474c3cd0e3ffaf57a8dd43c170e.jpg
#   inflating: test/images/I-Love-You_229_jpg.rf.e6e1c988c2e0f70e8ba06b0c3c04dd2d.jpg
#   inflating: test/images/I-Love-You_326_jpg.rf.8ca76dee76a75ed42b114436f5829199.jpg
#   inflating: test/images/Please_027_jpg.rf.1cb41b05b16a125eb1740c33b1bbad53.jpg
#   inflating: test/images/Please_159_jpg.rf.1d637474dd60ff3c5c5d3a4dfbd6a8c1.jpg
#   inflating: test/images/Thanks_169_jpg.rf.61ea0a9e6c69aa9075faffc14b972d9a.jpg
#   inflating: test/images/Yes_052_jpg.rf.d3e6017e6b2a34a3770d1bdc114a6c7c.jpg
#   inflating: test/images/Yes_146_jpg.rf.5132788836882c6b9fd0fadf8444132a.jpg
#   inflating: test/images/Yes_332_jpg.rf.449e62681ed5b5cb20b70167337a6cf3.jpg
#    creating: test/labels/
# ...

# %%
# !yolo task=detect mode=train data="/content/data.yaml" model="yolov8n.pt" epochs=100 imgsz=640
# Out:
# ...
# 100% 6.25M/6.25M [00:00<00:00, 329MB/s]
# Ultralytics 8.3.59 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
Image("/content/runs/detect/train/confusion_matrix.png", width=600)

# %%
Image("/content/runs/detect/train/labels.jpg", width=600)

# %%
Image("/content/runs/detect/train/results.png", width=600)

# %%
Image("/content/runs/detect/train/train_batch0.jpg", width=600)

# %%
Image("/content/runs/detect/train/val_batch0_pred.jpg", width=600)

# %%
# !yolo task=detect mode=predict model="/content/runs/detect/train/weights/best.pt" conf=0.25 source="/content/test/images" save=True
# Out:
# Ultralytics 8.3.59 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3,006,818 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/10 /content/test/images/Hello_289_jpg.rf.134d81f2adbf896271ef1ddd071ebbe9.jpg: 640x640 1 Hello, 10.1ms
# image 2/10 /content/test/images/I-Love-You_109_jpg.rf.46aca474c3cd0e3ffaf57a8dd43c170e.jpg: 640x640 1 I Love You, 7.4ms
# image 3/10 /content/test/images/I-Love-You_229_jpg.rf.e6e1c988c2e0f70e8ba06b0c3c04dd2d.jpg: 640x640 1 I Love You, 7.3ms
# image 4/10 /content/test/images/I-Love-You_326_jpg.rf.8ca76dee76a75ed42b114436f5829199.jpg: 640x640 1 I Love You, 7.4ms
# image 5/10 /content/test/images/Please_027_jpg.rf.1cb41b05b16a125eb1740c33b1bbad53.jpg: 640x640 1 Please, 7.4ms
# image 6/10 /content/test/images/Please_159_jpg.rf.1d637474dd60ff3c5c5d3a4dfbd6a8c1.jpg: 640x640 1 Please, 7.4ms
# image 7/10 /content/test/images/Thanks_169_jpg.rf.61ea0a9e6c69aa9075faffc14b972d9a.jpg: 640x640 1 Thanks, 7.4ms
# ...

# %%
import glob
import os
from IPython.display import Image as IPyImage, display

latest_folder = max(glob.glob('/content/runs/detect/predict*/'), key=os.path.getmtime)
for img in glob.glob(f'{latest_folder}/*.jpg')[1:4]:
    display(IPyImage(filename=img, width=600))
    print("\n")

# %%
Image("/content/runs/detect/train/F1_curve.png", width=600)
